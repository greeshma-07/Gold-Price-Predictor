# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df=pd.read_csv("gld.csv")
df.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
sns.scatterplot(x="SPX", y="EUR/USD", data=df)
# Out:
# <Axes: xlabel='SPX', ylabel='EUR/USD'>

# %%
sns.scatterplot(x="USO", y="EUR/USD", data=df)
# Out:
# <Axes: xlabel='USO', ylabel='EUR/USD'>

# %%
sns.scatterplot(x="SLV", y="EUR/USD", data=df)
# Out:
# <Axes: xlabel='SLV', ylabel='EUR/USD'>

# %%
sns.scatterplot(x="GLD", y="EUR/USD", data=df)
# Out:
# <Axes: xlabel='GLD', ylabel='EUR/USD'>

# %%
sns.scatterplot(x="Date", y="EUR/USD", data=df)
# Out:
# <Axes: xlabel='Date', ylabel='EUR/USD'>

# %%
sns.pairplot(df)
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#SLV and GLD have a positive correlation
#EUR/USD and USO have a positive correlation

# %%
X=df[["SPX","GLD","USO","SLV"]]
Y=df["EUR/USD"]

# %%
X.head()
# Out:
#            SPX        GLD        USO     SLV
# 0  1447.160034  84.860001  78.470001  15.180
# 1  1447.160034  85.570000  78.370003  15.285
# 2  1411.630005  85.129997  77.309998  15.167
# 3  1416.180054  84.769997  75.500000  15.053
# 4  1390.189941  86.779999  76.059998  15.590

# %%
Y.head()
# Out:
# 0    1.471692
# 1    1.474491
# 2    1.475492
# 3    1.468299
# 4    1.557099
# Name: EUR/USD, dtype: float64

# %%
x_train, x_test, y_train, y_test= train_test_split(X,Y, test_size=0.3 ,random_state=50)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictions=lr.predict(x_test)

# %%
predictions
# Out:
# array([1.33205255, 1.14264907, 1.38800489, 1.11218789, 1.26957056,
#        1.12462002, 1.13717177, 1.41216301, 1.15446063, 1.32961701,
#        1.14929291, 1.35339773, 1.16498582, 1.29390663, 1.3517988 ,
#        1.47537134, 1.28590071, 1.37876921, 1.33605391, 1.3117702 ,
#        1.29408013, 1.32660194, 1.17750266, 1.29254801, 1.31848264,
#        1.41677884, 1.28355454, 1.43510562, 1.14944396, 1.15109305,
#        1.42893966, 1.28791314, 1.16337636, 1.28862388, 1.1873735 ,
#        1.31420191, 1.23308685, 1.35503124, 1.4783679 , 1.3260651 ,
#        1.15277076, 1.15635745, 1.37154836, 1.30947952, 1.13868157,
#        1.31668284, 1.30794869, 1.31742254, 1.34299982, 1.3244294 ,
#        1.15285033, 1.29338276, 1.32063032, 1.2870222 , 1.12470905,
#        1.28655477, 1.54428289, 1.15441546, 1.55780367, 1.6135667 ,
#        1.32710245, 1.11682595, 1.3140212 , 1.15223169, 1.17102936,
#        1.19733308, 1.35290681, 1.1300268 , 1.3379523 , 1.15461012,
# ...

# %%
sns.scatterplot(x=y_test, y=predictions)
# Out:
# <Axes: xlabel='EUR/USD'>

# %%
MAB=mean_absolute_error(y_test, predictions)
# print(f"{MAB:.2f}")
MAB
# Out:
# 0.05178711702348843

# %%
MSE=mean_squared_error(y_test,predictions)
MSE
# Out:
# 0.0038654977382206164
